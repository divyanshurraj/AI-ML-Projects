# %%
import pywhatkit as kit
kit.image_to_ascii_art("C:/Users/INDIAN/Documents/3rd sem/3rd sem/download1.png","ascii.txt") #enter image path then image na
# Out:
# '................................................................................\n................................................................................\n................................................................................\n................................................................................\n................................................................................\n................................................................................\n....:!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!:....\n....%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@%....\n....%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@$%*%$@@@@@@@@@@@%....\n....%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@$*!::!*:....*@@@@@@@@@@%....\n....%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@!...........:$@@@@@@@@@%....\n....%@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@*..........:%@@@@@@@@@@%....\n....%@@@@@@@@
# ...

# %% [markdown]
# # Other Method

# %%
import ascii_magic
output = ascii_magic.from_image_file("C:/Users/INDIAN/Documents/3rd sem/3rd sem/download.png",columns = 500,char ="-")
ascii_magic.to_terminal(output)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
